# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
import warnings
warnings.filterwarnings('ignore')

import os
cwd = os.getcwd().split('\\')
local_repo_path = '\\'.join(cwd[:-1])
raw_data_path = local_repo_path + '\\data\\raw'
processed_data_path = local_repo_path + '\\data\\processed'
feature_path = local_repo_path + '\\data\\features'
model_path = local_repo_path + '\\model_submissions'

# %%
output_feature_fname = 'Lookback10'
sj_feature_train = pd.read_csv(feature_path + r'\\sj_train_' + output_feature_fname + '.csv', index_col = 0)
sj_feature_test = pd.read_csv(feature_path + r'\\sj_test_' + output_feature_fname + '.csv', index_col = 0)
iq_feature_train = pd.read_csv(feature_path + r'\\iq_train_' + output_feature_fname + '.csv', index_col = 0)
iq_feature_test = pd.read_csv(feature_path + r'\\iq_test_' + output_feature_fname + '.csv', index_col = 0)

# %%
sj_feature_test.head()
# Out:
#    var1(t-10)  var2(t-10)  var3(t-10)  var4(t-10)  var5(t-10)  var1(t-9)  \
# 0   -0.880088   -0.902578   -0.992343   -0.500000   -0.261864  -1.099356
# 1   -1.099356   -1.148990   -1.059724   -0.772727   -0.300411  -0.904755
# 2   -0.904755   -0.934355   -0.900459   -0.772727   -0.338042  -1.193641
# 3   -1.193641   -1.268293   -0.808576   -0.272727   -0.374707  -1.187611
# 4   -1.187611   -1.264948   -0.863706   -1.000000   -0.409986  -1.223242
#
#    var2(t-9)  var3(t-9)  var4(t-9)  var5(t-9)  ...  var4(t-2)  var5(t-2)  \
# 0  -1.148990  -1.059724  -0.772727  -0.300411  ...  -0.500000  -0.520492
# 1  -0.934355  -0.900459  -0.772727  -0.338042  ...   0.227273  -0.535167
# 2  -1.268293  -0.808576  -0.272727  -0.374707  ...  -0.500000  -0.542448
# 3  -1.264948  -0.863706  -1.000000  -0.409986  ...  -0.272727  -0.541333
# 4  -1.307875  -0.931087  -0.772727  -0.443178  ...   0.000000  -0.530953
#
#    var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)  city  year  \
# 0  -0.445389  -0.455470  -0.073507   0.227273  -0.535167    sj  2008
# 1  -0.350555  -0.359024  -0.294028  -0.500000  -0.542448    sj  2008
# 2  -0.399342  -0.410314  -0.490046  -0.272727  -0.541333    sj  2008
# 3  -0.060573  -0.054077   0.306279   0.000000  -0.530953    sj  2008
# 4  -0.405372  -0.407526   0.361409   0.727273  -0.510605    sj  2008
#
#    weekofyear
# 0          18
# 1          19
# 2          20
# 3          21
# 4          22
#
# [5 rows x 53 columns]

# %%
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from math import sqrt
from matplotlib import pyplot
from numpy import array
from sklearn.metrics import mean_absolute_error
# Out:
# Using TensorFlow backend.

# %%
def fit_and_predict_LSTM(train_wide, test_wide, epochs = 200, n_hidden = 25, activation = 'linear', verbose = 0):
    values = train_wide.values
    n_train = values.shape[0] - 200
    train = values[:n_train, :]
    val = values[n_train:, :]
    
    train_x, train_y = train[:, :-1], train[:, -1]
    val_x, val_y = val[:, :-1], val[:, -1]
    
    train_x = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
    val_x = val_x.reshape((val_x.shape[0], 1, val_x.shape[1]))
    test_x = test_wide.drop(['city', 'year', 'weekofyear'], axis = 1).values
    test_x = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))
    
    model = Sequential()
    model.add(LSTM(n_hidden, input_shape=(train_x.shape[1], train_x.shape[2])))
    model.add(Dropout(0.4))
    model.add(Dense(n_hidden))
    model.add(Dropout(0.4))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')
    
    history = model.fit(train_x, train_y, epochs = epochs, batch_size = 72, validation_data = (val_x, val_y), verbose = verbose, shuffle = False)
    
    plt.figure(figsize = (7,5))
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='val')
    plt.legend()
    plt.show()
    
    test_preds = model.predict(test_x)
    
    train_x_full = values[:, :-1]
    train_preds = model.predict(train_x_full.reshape((train_x_full.shape[0], 1, train_x_full.shape[1])))
    fig, ax = plt.subplots(figsize = (20,10))
    train_error = np.round(mean_absolute_error(train_preds, train_wide['total_cases']), 1)
    pd.DataFrame(train_preds).plot(ax = ax)
    pd.DataFrame(train_wide['total_cases']).reset_index(drop = True).plot(ax = ax)
    pd.DataFrame(test_preds).set_index(np.arange(len(train_wide), len(train_wide) + len(test_preds))).plot(ax = ax)
    
    ax.legend(labels = ['Fitted', 'True', 'Predicted'])
    ax.set_title('Mean train error: ' + str(train_error))
    return(model, train_preds, test_preds)

# %%
sj_feature_train_log_cases = sj_feature_train.copy()
sj_feature_train_log_cases['total_cases'] = np.log(1 + sj_feature_train_log_cases['total_cases'])

# %%
sj_model, sj_train_preds, sj_test_preds = fit_and_predict_LSTM(sj_feature_train, sj_feature_test, epochs = 400, n_hidden = 40, verbose = 2)
# Out:
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 726 samples, validate on 200 samples
# Epoch 1/400
#  - 1s - loss: 37.2367 - val_loss: 23.6734
# Epoch 2/400
#  - 0s - loss: 36.8608 - val_loss: 23.3263
# Epoch 3/400
#  - 0s - loss: 36.3576 - val_loss: 23.0240
# Epoch 4/400
#  - 0s - loss: 35.7308 - val_loss: 22.8107
# Epoch 5/400
#  - 0s - loss: 35.1906 - val_loss: 22.6275
# Epoch 6/400
#  - 0s - loss: 34.4387 - val_loss: 22.3886
# Epoch 7/400
#  - 0s - loss: 33.9465 - val_loss: 22.0735
# Epoch 8/400
#  - 0s - loss: 33.2622 - val_loss: 21.5962
# Epoch 9/400
#  - 0s - loss: 32.5180 - val_loss: 20.8917
# Epoch 10/400
#  - 0s - loss: 31.8403 - val_loss: 19.9588
# Epoch 11/400
#  - 0s - loss: 30.9221 - val_loss: 18.9729
# Epoch 12/400
#  - 0s - loss: 29.8963 - val_loss: 18.0143
# Epoch 13/400
#  - 0s - loss: 28.9796 - val_loss: 17.4153
# Epoch 14/400
#  - 0s - loss: 27.7982 - val_loss: 17.2694
# Epoch 15/400
#  - 0s - loss: 26.7581 - val_loss: 17.2144
# Epoch 16/400
#  - 0s - loss: 26.2469 - val_loss: 17.3140
# Epoch 17/400
#  - 0s - loss: 24.9773 - val_loss: 17.6094
# Epoch 18/400
#  - 0s - loss: 24.9342 - val_loss: 17.9648
# Epoch 19/400
#  - 0s - loss: 24.3321 - val_loss: 18.0745
# Epoch 20/400
#  - 0s - loss: 24.2213 - val_loss: 18.0215
# Epoch 21/400
#  - 0s - loss: 24.1171 - val_loss: 18.1963
# Epoch 22/400
#  - 0s - loss: 23.8174 - val_loss: 18.3141
# Epoch 23/400
#  - 0s - loss: 23.3628 - val_loss: 18.3078
# Epoch 24/400
#  - 0s - loss: 23.8783 - val_loss: 18.3728
# Epoch 25/400
#  - 0s - loss: 23.9546 - val_loss: 18.3280
# Epoch 26/400
#  - 0s - loss: 23.6046 - val_loss: 18.2655
# Epoch 27/400
#  - 0s - loss: 23.5160 - val_loss: 18.4096
# Epoch 28/400
#  - 0s - loss: 23.2073 - val_loss: 18.5210
# Epoch 29/400
#  - 0s - loss: 23.5291 - val_loss: 18.5338
# Epoch 30/400
#  - 0s - loss: 24.0908 - val_loss: 18.4467
# Epoch 31/400
#  - 0s - loss: 23.5276 - val_loss: 18.4978
# Epoch 32/400
#  - 0s - loss: 23.4871 - val_loss: 18.5357
# Epoch 33/400
#  - 0s - loss: 23.6637 - val_loss: 18.5700
# Epoch 34/400
#  - 0s - loss: 23.5350 - val_loss: 18.4681
# Epoch 35/400
#  - 0s - loss: 23.3677 - val_loss: 18.4921
# Epoch 36/400
#  - 0s - loss: 23.6501 - val_loss: 18.4599
# Epoch 37/400
#  - 0s - loss: 23.2812 - val_loss: 18.3461
# Epoch 38/400
#  - 0s - loss: 23.2803 - val_loss: 18.2808
# Epoch 39/400
#  - 0s - loss: 23.5099 - val_loss: 18.3163
# Epoch 40/400
#  - 0s - loss: 23.4737 - val_loss: 18.2543
# Epoch 41/400
#  - 0s - loss: 23.1568 - val_loss: 18.1883
# Epoch 42/400
#  - 0s - loss: 23.5602 - val_loss: 18.1177
# Epoch 43/400
#  - 0s - loss: 23.1051 - val_loss: 18.1945
# Epoch 44/400
#  - 0s - loss: 23.3697 - val_loss: 18.1979
# Epoch 45/400
#  - 0s - loss: 23.6007 - val_loss: 18.2182
# Epoch 46/400
#  - 0s - loss: 23.3192 - val_loss: 18.1176
# Epoch 47/400
#  - 0s - loss: 23.3089 - val_loss: 18.2014
# Epoch 48/400
#  - 0s - loss: 22.9503 - val_loss: 18.2035
# Epoch 49/400
#  - 0s - loss: 23.4734 - val_loss: 18.1649
# Epoch 50/400
#  - 0s - loss: 23.4912 - val_loss: 18.2590
# Epoch 51/400
#  - 0s - loss: 23.3416 - val_loss: 18.3716
# Epoch 52/400
#  - 0s - loss: 23.4727 - val_loss: 18.3954
# Epoch 53/400
#  - 0s - loss: 23.0639 - val_loss: 18.4121
# Epoch 54/400
#  - 0s - loss: 23.0932 - val_loss: 18.2722
# Epoch 55/400
#  - 0s - loss: 23.3196 - val_loss: 18.1432
# Epoch 56/400
#  - 0s - loss: 23.4490 - val_loss: 18.0632
# Epoch 57/400
#  - 0s - loss: 23.2353 - val_loss: 18.2189
# Epoch 58/400
#  - 0s - loss: 23.0827 - val_loss: 18.2927
# Epoch 59/400
#  - 0s - loss: 23.1842 - val_loss: 18.3711
# Epoch 60/400
#  - 0s - loss: 23.3922 - val_loss: 18.4397
# Epoch 61/400
#  - 0s - loss: 23.0640 - val_loss: 18.4924
# Epoch 62/400
#  - 0s - loss: 23.0949 - val_loss: 18.4519
# Epoch 63/400
#  - 0s - loss: 22.9329 - val_loss: 18.2562
# Epoch 64/400
#  - 0s - loss: 23.2327 - val_loss: 18.2377
# Epoch 65/400
#  - 0s - loss: 22.8313 - val_loss: 18.2408
# Epoch 66/400
#  - 0s - loss: 23.0125 - val_loss: 18.2374
# Epoch 67/400
#  - 0s - loss: 22.9611 - val_loss: 18.2874
# Epoch 68/400
#  - 0s - loss: 23.4770 - val_loss: 18.3235
# Epoch 69/400
#  - 0s - loss: 23.0384 - val_loss: 18.3526
# Epoch 70/400
#  - 0s - loss: 22.9681 - val_loss: 18.2131
# Epoch 71/400
#  - 0s - loss: 23.0754 - val_loss: 18.1307
# Epoch 72/400
#  - 0s - loss: 22.9112 - val_loss: 18.1729
# Epoch 73/400
#  - 0s - loss: 22.6270 - val_loss: 18.2784
# Epoch 74/400
#  - 0s - loss: 22.8646 - val_loss: 18.2791
# Epoch 75/400
#  - 0s - loss: 23.4353 - val_loss: 18.3047
# Epoch 76/400
#  - 0s - loss: 23.4604 - val_loss: 18.3745
# Epoch 77/400
#  - 0s - loss: 22.9440 - val_loss: 18.3415
# Epoch 78/400
#  - 0s - loss: 22.6312 - val_loss: 18.3825
# Epoch 79/400
#  - 0s - loss: 22.7128 - val_loss: 18.3730
# Epoch 80/400
#  - 0s - loss: 22.8721 - val_loss: 18.1632
# Epoch 81/400
#  - 0s - loss: 22.6383 - val_loss: 18.1392
# Epoch 82/400
#  - 0s - loss: 23.0658 - val_loss: 18.2068
# Epoch 83/400
#  - 0s - loss: 22.8728 - val_loss: 18.0400
# Epoch 84/400
#  - 0s - loss: 23.0846 - val_loss: 18.1350
# Epoch 85/400
#  - 0s - loss: 22.8482 - val_loss: 18.1133
# Epoch 86/400
#  - 0s - loss: 22.9311 - val_loss: 18.1918
# Epoch 87/400
#  - 0s - loss: 23.3584 - val_loss: 18.2371
# Epoch 88/400
#  - 0s - loss: 22.8193 - val_loss: 18.3558
# Epoch 89/400
#  - 0s - loss: 22.5052 - val_loss: 18.4334
# Epoch 90/400
#  - 0s - loss: 22.7547 - val_loss: 18.4021
# Epoch 91/400
#  - 0s - loss: 23.1788 - val_loss: 18.2285
# Epoch 92/400
#  - 0s - loss: 22.7810 - val_loss: 18.2018
# Epoch 93/400
#  - 0s - loss: 22.9792 - val_loss: 18.1482
# Epoch 94/400
#  - 0s - loss: 22.6263 - val_loss: 18.1815
# Epoch 95/400
#  - 0s - loss: 22.6374 - val_loss: 18.3673
# Epoch 96/400
#  - 0s - loss: 23.0509 - val_loss: 18.6322
# Epoch 97/400
#  - 0s - loss: 22.5944 - val_loss: 18.6605
# Epoch 98/400
#  - 0s - loss: 22.9775 - val_loss: 18.6514
# Epoch 99/400
#  - 0s - loss: 22.9440 - val_loss: 18.5882
# Epoch 100/400
#  - 0s - loss: 22.9074 - val_loss: 18.5256
# Epoch 101/400
#  - 0s - loss: 22.7938 - val_loss: 18.5233
# Epoch 102/400
#  - 0s - loss: 22.5388 - val_loss: 18.4162
# Epoch 103/400
#  - 0s - loss: 22.7589 - val_loss: 18.3281
# Epoch 104/400
#  - 0s - loss: 23.0951 - val_loss: 18.4209
# Epoch 105/400
#  - 0s - loss: 22.8131 - val_loss: 18.2915
# Epoch 106/400
#  - 0s - loss: 22.7067 - val_loss: 18.2730
# Epoch 107/400
#  - 0s - loss: 23.0097 - val_loss: 18.2987
# Epoch 108/400
#  - 0s - loss: 23.1040 - val_loss: 18.2333
# Epoch 109/400
#  - 0s - loss: 22.6079 - val_loss: 18.0954
# Epoch 110/400
#  - 0s - loss: 22.6993 - val_loss: 18.1615
# Epoch 111/400
#  - 0s - loss: 22.6016 - val_loss: 18.3482
# Epoch 112/400
#  - 0s - loss: 22.5688 - val_loss: 18.4180
# Epoch 113/400
#  - 0s - loss: 22.3948 - val_loss: 18.4424
# Epoch 114/400
#  - 0s - loss: 22.4975 - val_loss: 18.4090
# Epoch 115/400
#  - 0s - loss: 22.7103 - val_loss: 18.3916
# Epoch 116/400
#  - 0s - loss: 22.9856 - val_loss: 18.3905
# Epoch 117/400
#  - 0s - loss: 22.7762 - val_loss: 18.3489
# Epoch 118/400
#  - 0s - loss: 22.5196 - val_loss: 18.3006
# Epoch 119/400
#  - 0s - loss: 22.6511 - val_loss: 18.3917
# Epoch 120/400
#  - 0s - loss: 23.0078 - val_loss: 18.3736
# Epoch 121/400
#  - 0s - loss: 22.7805 - val_loss: 18.3279
# Epoch 122/400
#  - 0s - loss: 22.7369 - val_loss: 18.2816
# Epoch 123/400
#  - 0s - loss: 22.6237 - val_loss: 18.4234
# Epoch 124/400
#  - 0s - loss: 22.4293 - val_loss: 18.3843
# Epoch 125/400
#  - 0s - loss: 22.3264 - val_loss: 18.2683
# Epoch 126/400
#  - 0s - loss: 22.6212 - val_loss: 18.5234
# Epoch 127/400
#  - 0s - loss: 22.2256 - val_loss: 18.4264
# Epoch 128/400
#  - 0s - loss: 22.4433 - val_loss: 18.5601
# Epoch 129/400
#  - 0s - loss: 22.6741 - val_loss: 18.5200
# Epoch 130/400
#  - 0s - loss: 22.5840 - val_loss: 18.1872
# Epoch 131/400
#  - 0s - loss: 22.7418 - val_loss: 18.2241
# Epoch 132/400
#  - 0s - loss: 22.3163 - val_loss: 18.5299
# Epoch 133/400
#  - 0s - loss: 22.5400 - val_loss: 18.5943
# Epoch 134/400
#  - 0s - loss: 22.2883 - val_loss: 18.5499
# Epoch 135/400
#  - 0s - loss: 22.5350 - val_loss: 18.5161
# Epoch 136/400
#  - 0s - loss: 22.3653 - val_loss: 18.5044
# Epoch 137/400
#  - 0s - loss: 22.6324 - val_loss: 18.5403
# Epoch 138/400
#  - 0s - loss: 22.0785 - val_loss: 18.7622
# Epoch 139/400
#  - 0s - loss: 22.5564 - val_loss: 18.7658
# Epoch 140/400
#  - 0s - loss: 23.0436 - val_loss: 18.5673
# Epoch 141/400
#  - 0s - loss: 22.7124 - val_loss: 18.4705
# Epoch 142/400
#  - 0s - loss: 22.5853 - val_loss: 18.5442
# Epoch 143/400
#  - 0s - loss: 22.2518 - val_loss: 18.7440
# Epoch 144/400
#  - 0s - loss: 22.0526 - val_loss: 18.8942
# Epoch 145/400
#  - 0s - loss: 22.2936 - val_loss: 18.7642
# Epoch 146/400
#  - 0s - loss: 22.5532 - val_loss: 18.7669
# Epoch 147/400
#  - 0s - loss: 22.7024 - val_loss: 18.7494
# Epoch 148/400
#  - 0s - loss: 21.8903 - val_loss: 18.5838
# Epoch 149/400
#  - 0s - loss: 22.2645 - val_loss: 18.5652
# Epoch 150/400
#  - 0s - loss: 22.3620 - val_loss: 18.3902
# Epoch 151/400
#  - 0s - loss: 22.2942 - val_loss: 18.6200
# Epoch 152/400
#  - 0s - loss: 22.4236 - val_loss: 18.7297
# Epoch 153/400
#  - 0s - loss: 22.2787 - val_loss: 18.5673
# Epoch 154/400
#  - 0s - loss: 21.9420 - val_loss: 18.5288
# Epoch 155/400
#  - 0s - loss: 22.5544 - val_loss: 18.7448
# Epoch 156/400
#  - 0s - loss: 22.5997 - val_loss: 18.7540
# Epoch 157/400
#  - 0s - loss: 22.4601 - val_loss: 18.6099
# Epoch 158/400
#  - 0s - loss: 22.3474 - val_loss: 18.4576
# Epoch 159/400
#  - 0s - loss: 22.1435 - val_loss: 18.6032
# Epoch 160/400
#  - 0s - loss: 22.3028 - val_loss: 18.5452
# Epoch 161/400
#  - 0s - loss: 22.6056 - val_loss: 18.7355
# Epoch 162/400
#  - 0s - loss: 22.1327 - val_loss: 18.8916
# Epoch 163/400
#  - 0s - loss: 22.7727 - val_loss: 18.6943
# Epoch 164/400
#  - 0s - loss: 21.7902 - val_loss: 18.5139
# Epoch 165/400
#  - 0s - loss: 22.7478 - val_loss: 18.4592
# Epoch 166/400
#  - 0s - loss: 22.0282 - val_loss: 18.3791
# Epoch 167/400
#  - 0s - loss: 22.0520 - val_loss: 18.5165
# Epoch 168/400
#  - 0s - loss: 22.4674 - val_loss: 18.6614
# Epoch 169/400
#  - 0s - loss: 22.3751 - val_loss: 18.6924
# Epoch 170/400
#  - 0s - loss: 22.2225 - val_loss: 18.7640
# Epoch 171/400
#  - 0s - loss: 22.2821 - val_loss: 18.8112
# Epoch 172/400
#  - 0s - loss: 22.1100 - val_loss: 18.9267
# Epoch 173/400
#  - 0s - loss: 22.2983 - val_loss: 18.7552
# Epoch 174/400
#  - 0s - loss: 22.2235 - val_loss: 18.7027
# Epoch 175/400
#  - 0s - loss: 22.0577 - val_loss: 18.6910
# Epoch 176/400
#  - 0s - loss: 21.9562 - val_loss: 18.5354
# Epoch 177/400
#  - 0s - loss: 22.1661 - val_loss: 18.6200
# Epoch 178/400
#  - 0s - loss: 22.1964 - val_loss: 18.9027
# Epoch 179/400
#  - 0s - loss: 22.3450 - val_loss: 18.9856
# Epoch 180/400
#  - 0s - loss: 21.8021 - val_loss: 18.9575
# Epoch 181/400
#  - 0s - loss: 22.3409 - val_loss: 18.9201
# Epoch 182/400
#  - 0s - loss: 21.9891 - val_loss: 18.7432
# Epoch 183/400
#  - 0s - loss: 22.2956 - val_loss: 18.6122
# Epoch 184/400
#  - 0s - loss: 22.0032 - val_loss: 18.5483
# Epoch 185/400
#  - 0s - loss: 22.2967 - val_loss: 18.7357
# Epoch 186/400
#  - 0s - loss: 21.9572 - val_loss: 18.9024
# Epoch 187/400
#  - 0s - loss: 21.5769 - val_loss: 18.7678
# Epoch 188/400
#  - 0s - loss: 21.9112 - val_loss: 18.7454
# Epoch 189/400
#  - 0s - loss: 21.6453 - val_loss: 18.5986
# Epoch 190/400
#  - 0s - loss: 21.7400 - val_loss: 18.6469
# Epoch 191/400
#  - 0s - loss: 22.0916 - val_loss: 18.8138
# Epoch 192/400
#  - 0s - loss: 22.0441 - val_loss: 19.0097
# Epoch 193/400
#  - 0s - loss: 22.2757 - val_loss: 18.8816
# Epoch 194/400
#  - 0s - loss: 21.4544 - val_loss: 18.7743
# Epoch 195/400
#  - 0s - loss: 22.2815 - val_loss: 18.6697
# Epoch 196/400
#  - 0s - loss: 22.1817 - val_loss: 18.5341
# Epoch 197/400
#  - 0s - loss: 21.7636 - val_loss: 18.5798
# Epoch 198/400
#  - 0s - loss: 22.5802 - val_loss: 18.8039
# Epoch 199/400
#  - 0s - loss: 22.1241 - val_loss: 18.9752
# Epoch 200/400
#  - 0s - loss: 21.9816 - val_loss: 19.1640
# Epoch 201/400
#  - 0s - loss: 22.4282 - val_loss: 19.0369
# Epoch 202/400
#  - 0s - loss: 21.8708 - val_loss: 18.8239
# Epoch 203/400
#  - 0s - loss: 21.8348 - val_loss: 18.4823
# Epoch 204/400
#  - 0s - loss: 22.4468 - val_loss: 18.5873
# Epoch 205/400
#  - 0s - loss: 22.1615 - val_loss: 18.6497
# Epoch 206/400
#  - 0s - loss: 21.6371 - val_loss: 18.5290
# Epoch 207/400
#  - 0s - loss: 21.5819 - val_loss: 18.6915
# Epoch 208/400
#  - 0s - loss: 21.8511 - val_loss: 18.8189
# Epoch 209/400
#  - 0s - loss: 22.0304 - val_loss: 18.9699
# Epoch 210/400
#  - 0s - loss: 21.7178 - val_loss: 19.0209
# Epoch 211/400
#  - 0s - loss: 21.8379 - val_loss: 18.7982
# Epoch 212/400
#  - 0s - loss: 21.8177 - val_loss: 18.7669
# Epoch 213/400
#  - 0s - loss: 22.0637 - val_loss: 18.6980
# Epoch 214/400
#  - 0s - loss: 22.2934 - val_loss: 18.6737
# Epoch 215/400
#  - 0s - loss: 21.8622 - val_loss: 18.7329
# Epoch 216/400
#  - 0s - loss: 22.0431 - val_loss: 18.9592
# Epoch 217/400
#  - 0s - loss: 21.5128 - val_loss: 18.9602
# Epoch 218/400
#  - 0s - loss: 21.7853 - val_loss: 18.9395
# Epoch 219/400
#  - 0s - loss: 22.1863 - val_loss: 18.9251
# Epoch 220/400
#  - 0s - loss: 22.0871 - val_loss: 19.0306
# Epoch 221/400
#  - 0s - loss: 21.9385 - val_loss: 19.0705
# Epoch 222/400
#  - 0s - loss: 21.6359 - val_loss: 19.1632
# Epoch 223/400
#  - 0s - loss: 22.2851 - val_loss: 19.0358
# Epoch 224/400
#  - 0s - loss: 21.8994 - val_loss: 18.8093
# Epoch 225/400
#  - 0s - loss: 21.6896 - val_loss: 18.9557
# Epoch 226/400
#  - 0s - loss: 22.1740 - val_loss: 19.0749
# Epoch 227/400
#  - 0s - loss: 21.7773 - val_loss: 19.0095
# Epoch 228/400
#  - 0s - loss: 22.0917 - val_loss: 19.0709
# Epoch 229/400
#  - 0s - loss: 21.8766 - val_loss: 19.1174
# Epoch 230/400
#  - 0s - loss: 21.4963 - val_loss: 18.9477
# Epoch 231/400
#  - 0s - loss: 21.6303 - val_loss: 18.8808
# Epoch 232/400
#  - 0s - loss: 21.6398 - val_loss: 18.7704
# Epoch 233/400
#  - 0s - loss: 22.0079 - val_loss: 18.8299
# Epoch 234/400
#  - 0s - loss: 21.5875 - val_loss: 18.8978
# Epoch 235/400
#  - 0s - loss: 21.9466 - val_loss: 19.0165
# Epoch 236/400
#  - 0s - loss: 21.9257 - val_loss: 19.0416
# Epoch 237/400
#  - 0s - loss: 21.4317 - val_loss: 19.1137
# Epoch 238/400
#  - 0s - loss: 22.0338 - val_loss: 19.1845
# Epoch 239/400
#  - 0s - loss: 21.7407 - val_loss: 19.0618
# Epoch 240/400
#  - 0s - loss: 21.8440 - val_loss: 18.8899
# Epoch 241/400
#  - 0s - loss: 21.7164 - val_loss: 18.7226
# Epoch 242/400
#  - 0s - loss: 21.7196 - val_loss: 18.7956
# Epoch 243/400
#  - 0s - loss: 21.8888 - val_loss: 18.7459
# Epoch 244/400
#  - 0s - loss: 21.5180 - val_loss: 18.5483
# Epoch 245/400
#  - 0s - loss: 21.9631 - val_loss: 18.5445
# Epoch 246/400
#  - 0s - loss: 21.6584 - val_loss: 18.7783
# Epoch 247/400
#  - 0s - loss: 21.9939 - val_loss: 18.8895
# Epoch 248/400
#  - 0s - loss: 21.4943 - val_loss: 18.7820
# Epoch 249/400
#  - 0s - loss: 21.9518 - val_loss: 18.7402
# Epoch 250/400
#  - 0s - loss: 21.5383 - val_loss: 18.7359
# Epoch 251/400
#  - 0s - loss: 21.8943 - val_loss: 18.6818
# Epoch 252/400
#  - 0s - loss: 21.5506 - val_loss: 18.8217
# Epoch 253/400
#  - 0s - loss: 21.7337 - val_loss: 18.9784
# Epoch 254/400
#  - 0s - loss: 22.0112 - val_loss: 18.8757
# Epoch 255/400
#  - 0s - loss: 21.9986 - val_loss: 18.5324
# Epoch 256/400
#  - 0s - loss: 21.9254 - val_loss: 18.4427
# Epoch 257/400
#  - 0s - loss: 22.0330 - val_loss: 18.4211
# Epoch 258/400
#  - 0s - loss: 21.3964 - val_loss: 18.5102
# Epoch 259/400
#  - 0s - loss: 21.4965 - val_loss: 18.6294
# Epoch 260/400
#  - 0s - loss: 22.1615 - val_loss: 18.7966
# Epoch 261/400
#  - 0s - loss: 21.7469 - val_loss: 18.9435
# Epoch 262/400
#  - 0s - loss: 21.7060 - val_loss: 19.2151
# Epoch 263/400
#  - 0s - loss: 21.6604 - val_loss: 19.1055
# Epoch 264/400
#  - 0s - loss: 21.6339 - val_loss: 19.2298
# Epoch 265/400
#  - 0s - loss: 21.8900 - val_loss: 19.2416
# Epoch 266/400
#  - 0s - loss: 22.0069 - val_loss: 19.2677
# Epoch 267/400
#  - 0s - loss: 21.7955 - val_loss: 19.3783
# Epoch 268/400
#  - 0s - loss: 21.4891 - val_loss: 19.2070
# Epoch 269/400
#  - 0s - loss: 21.3985 - val_loss: 19.1337
# Epoch 270/400
#  - 0s - loss: 21.6884 - val_loss: 19.1719
# Epoch 271/400
#  - 0s - loss: 21.7734 - val_loss: 19.1122
# Epoch 272/400
#  - 0s - loss: 21.7551 - val_loss: 18.9752
# Epoch 273/400
#  - 0s - loss: 21.5150 - val_loss: 18.8522
# Epoch 274/400
#  - 0s - loss: 21.3594 - val_loss: 19.0856
# Epoch 275/400
#  - 0s - loss: 21.5573 - val_loss: 19.2067
# Epoch 276/400
#  - 0s - loss: 21.9111 - val_loss: 19.3320
# Epoch 277/400
#  - 0s - loss: 21.5625 - val_loss: 19.1031
# Epoch 278/400
#  - 0s - loss: 21.7337 - val_loss: 19.0544
# Epoch 279/400
#  - 0s - loss: 21.7777 - val_loss: 19.1298
# Epoch 280/400
#  - 0s - loss: 21.3704 - val_loss: 19.0176
# Epoch 281/400
#  - 0s - loss: 21.7629 - val_loss: 18.7993
# Epoch 282/400
#  - 0s - loss: 21.9135 - val_loss: 18.6882
# Epoch 283/400
#  - 0s - loss: 21.6285 - val_loss: 18.8515
# Epoch 284/400
#  - 0s - loss: 21.7682 - val_loss: 19.1120
# Epoch 285/400
#  - 0s - loss: 21.8709 - val_loss: 19.1313
# Epoch 286/400
#  - 0s - loss: 21.2084 - val_loss: 19.0341
# Epoch 287/400
#  - 0s - loss: 21.5211 - val_loss: 18.9576
# Epoch 288/400
#  - 0s - loss: 21.4098 - val_loss: 19.1162
# Epoch 289/400
#  - 0s - loss: 21.6043 - val_loss: 19.0528
# Epoch 290/400
#  - 0s - loss: 22.0147 - val_loss: 18.9696
# Epoch 291/400
#  - 0s - loss: 21.3102 - val_loss: 19.0400
# Epoch 292/400
#  - 0s - loss: 21.2519 - val_loss: 19.0259
# Epoch 293/400
#  - 0s - loss: 21.3974 - val_loss: 18.8922
# Epoch 294/400
#  - 0s - loss: 21.3877 - val_loss: 18.8078
# Epoch 295/400
#  - 0s - loss: 20.8936 - val_loss: 18.8262
# Epoch 296/400
#  - 0s - loss: 21.1162 - val_loss: 18.8972
# Epoch 297/400
#  - 0s - loss: 21.0353 - val_loss: 18.9360
# Epoch 298/400
#  - 0s - loss: 21.7758 - val_loss: 18.9104
# Epoch 299/400
#  - 0s - loss: 21.5559 - val_loss: 18.7662
# Epoch 300/400
#  - 0s - loss: 21.0948 - val_loss: 18.7567
# Epoch 301/400
#  - 0s - loss: 21.5920 - val_loss: 18.8287
# Epoch 302/400
#  - 0s - loss: 21.6815 - val_loss: 18.9129
# Epoch 303/400
#  - 0s - loss: 21.2490 - val_loss: 18.9942
# Epoch 304/400
#  - 0s - loss: 21.4643 - val_loss: 19.1628
# Epoch 305/400
#  - 0s - loss: 21.5055 - val_loss: 19.1120
# Epoch 306/400
#  - 0s - loss: 21.1899 - val_loss: 18.9588
# Epoch 307/400
#  - 0s - loss: 21.3698 - val_loss: 18.9324
# Epoch 308/400
#  - 0s - loss: 21.5516 - val_loss: 18.9842
# Epoch 309/400
#  - 0s - loss: 20.9637 - val_loss: 19.0827
# Epoch 310/400
#  - 0s - loss: 21.2697 - val_loss: 19.2350
# Epoch 311/400
#  - 0s - loss: 21.7258 - val_loss: 19.2377
# Epoch 312/400
#  - 0s - loss: 21.0144 - val_loss: 19.1560
# Epoch 313/400
#  - 0s - loss: 21.1210 - val_loss: 19.1662
# Epoch 314/400
#  - 0s - loss: 21.1783 - val_loss: 19.3582
# Epoch 315/400
#  - 0s - loss: 21.3591 - val_loss: 19.2901
# Epoch 316/400
#  - 0s - loss: 21.5298 - val_loss: 18.9444
# Epoch 317/400
#  - 0s - loss: 21.3035 - val_loss: 19.0043
# Epoch 318/400
#  - 0s - loss: 20.9153 - val_loss: 19.2414
# Epoch 319/400
#  - 0s - loss: 21.0870 - val_loss: 19.1775
# Epoch 320/400
#  - 0s - loss: 21.3730 - val_loss: 19.2198
# Epoch 321/400
#  - 0s - loss: 21.0391 - val_loss: 19.0760
# Epoch 322/400
#  - 0s - loss: 21.5087 - val_loss: 18.9402
# Epoch 323/400
#  - 0s - loss: 21.2613 - val_loss: 18.8819
# Epoch 324/400
#  - 0s - loss: 21.4444 - val_loss: 18.9571
# Epoch 325/400
#  - 0s - loss: 20.8141 - val_loss: 18.8638
# Epoch 326/400
#  - 0s - loss: 21.0769 - val_loss: 18.9119
# Epoch 327/400
#  - 0s - loss: 20.9235 - val_loss: 19.1171
# Epoch 328/400
#  - 0s - loss: 20.9494 - val_loss: 18.8999
# Epoch 329/400
#  - 0s - loss: 21.3067 - val_loss: 18.9567
# Epoch 330/400
#  - 0s - loss: 20.9811 - val_loss: 18.9624
# Epoch 331/400
#  - 0s - loss: 21.0243 - val_loss: 19.1733
# Epoch 332/400
#  - 0s - loss: 21.3190 - val_loss: 19.2861
# Epoch 333/400
#  - 0s - loss: 21.4971 - val_loss: 19.2560
# Epoch 334/400
#  - 0s - loss: 21.3222 - val_loss: 19.3566
# Epoch 335/400
#  - 0s - loss: 21.3152 - val_loss: 19.3563
# Epoch 336/400
#  - 0s - loss: 21.4439 - val_loss: 19.3294
# Epoch 337/400
#  - 0s - loss: 21.0575 - val_loss: 19.2022
# Epoch 338/400
#  - 0s - loss: 21.3778 - val_loss: 19.0590
# Epoch 339/400
#  - 0s - loss: 20.9415 - val_loss: 19.0908
# Epoch 340/400
#  - 0s - loss: 21.1838 - val_loss: 19.0411
# Epoch 341/400
#  - 0s - loss: 21.3905 - val_loss: 19.2067
# Epoch 342/400
#  - 0s - loss: 20.9426 - val_loss: 19.0445
# Epoch 343/400
#  - 0s - loss: 20.8729 - val_loss: 18.8642
# Epoch 344/400
#  - 0s - loss: 21.5904 - val_loss: 18.7948
# Epoch 345/400
#  - 0s - loss: 21.0439 - val_loss: 18.9594
# Epoch 346/400
#  - 0s - loss: 21.3193 - val_loss: 19.1062
# Epoch 347/400
#  - 0s - loss: 21.0542 - val_loss: 19.1979
# Epoch 348/400
#  - 0s - loss: 21.1681 - val_loss: 19.1916
# Epoch 349/400
#  - 0s - loss: 21.2920 - val_loss: 19.1291
# Epoch 350/400
#  - 0s - loss: 20.7692 - val_loss: 19.1663
# Epoch 351/400
#  - 0s - loss: 20.9181 - val_loss: 19.0584
# Epoch 352/400
#  - 0s - loss: 20.6137 - val_loss: 18.8825
# Epoch 353/400
#  - 0s - loss: 20.9223 - val_loss: 18.7200
# Epoch 354/400
#  - 0s - loss: 20.9436 - val_loss: 18.9506
# Epoch 355/400
#  - 0s - loss: 21.3466 - val_loss: 19.0290
# Epoch 356/400
#  - 0s - loss: 21.0580 - val_loss: 19.1145
# Epoch 357/400
#  - 0s - loss: 21.0333 - val_loss: 19.1740
# Epoch 358/400
#  - 0s - loss: 20.5935 - val_loss: 19.2662
# Epoch 359/400
#  - 0s - loss: 20.9486 - val_loss: 19.1815
# Epoch 360/400
#  - 0s - loss: 20.9024 - val_loss: 19.2383
# Epoch 361/400
#  - 0s - loss: 21.0014 - val_loss: 19.2948
# Epoch 362/400
#  - 0s - loss: 20.8732 - val_loss: 19.2159
# Epoch 363/400
#  - 0s - loss: 21.1106 - val_loss: 19.1900
# Epoch 364/400
#  - 0s - loss: 20.9614 - val_loss: 18.9150
# Epoch 365/400
#  - 0s - loss: 21.3055 - val_loss: 18.9606
# Epoch 366/400
#  - 0s - loss: 20.9378 - val_loss: 18.9466
# Epoch 367/400
#  - 0s - loss: 21.1982 - val_loss: 18.7704
# Epoch 368/400
#  - 0s - loss: 20.5855 - val_loss: 18.8952
# Epoch 369/400
#  - 0s - loss: 20.7557 - val_loss: 19.3276
# Epoch 370/400
#  - 0s - loss: 21.0787 - val_loss: 19.3730
# Epoch 371/400
#  - 0s - loss: 21.1348 - val_loss: 19.3181
# Epoch 372/400
#  - 0s - loss: 20.7598 - val_loss: 19.4099
# Epoch 373/400
#  - 0s - loss: 20.9554 - val_loss: 19.1962
# Epoch 374/400
#  - 0s - loss: 20.8085 - val_loss: 18.9975
# Epoch 375/400
#  - 0s - loss: 20.4785 - val_loss: 19.1211
# Epoch 376/400
#  - 0s - loss: 20.6744 - val_loss: 19.2471
# Epoch 377/400
#  - 0s - loss: 20.9961 - val_loss: 19.7075
# Epoch 378/400
#  - 0s - loss: 20.9343 - val_loss: 19.3787
# Epoch 379/400
#  - 0s - loss: 20.7866 - val_loss: 19.1638
# Epoch 380/400
#  - 0s - loss: 21.3280 - val_loss: 19.3482
# Epoch 381/400
#  - 0s - loss: 20.8899 - val_loss: 19.2560
# Epoch 382/400
#  - 0s - loss: 20.9999 - val_loss: 19.3487
# Epoch 383/400
#  - 0s - loss: 20.7978 - val_loss: 19.3279
# Epoch 384/400
#  - 0s - loss: 21.1179 - val_loss: 19.5426
# Epoch 385/400
#  - 0s - loss: 21.2360 - val_loss: 19.5466
# Epoch 386/400
#  - 0s - loss: 20.8813 - val_loss: 19.2800
# Epoch 387/400
#  - 0s - loss: 20.5715 - val_loss: 19.2993
# Epoch 388/400
#  - 0s - loss: 20.9205 - val_loss: 19.4193
# Epoch 389/400
#  - 0s - loss: 20.7898 - val_loss: 19.2192
# Epoch 390/400
#  - 0s - loss: 20.7243 - val_loss: 19.2493
# Epoch 391/400
#  - 0s - loss: 20.8804 - val_loss: 19.2609
# Epoch 392/400
#  - 0s - loss: 20.4616 - val_loss: 19.1879
# Epoch 393/400
#  - 0s - loss: 20.9684 - val_loss: 19.1685
# Epoch 394/400
#  - 0s - loss: 20.6799 - val_loss: 19.2001
# Epoch 395/400
#  - 0s - loss: 20.7309 - val_loss: 19.1267
# Epoch 396/400
#  - 0s - loss: 20.4795 - val_loss: 18.9339
# Epoch 397/400
#  - 0s - loss: 20.9009 - val_loss: 18.9944
# Epoch 398/400
#  - 0s - loss: 20.6604 - val_loss: 19.2863
# Epoch 399/400
#  - 0s - loss: 20.4476 - val_loss: 19.4802
# Epoch 400/400
#  - 0s - loss: 20.5253 - val_loss: 19.6138

# %%
output_sj = pd.DataFrame(np.append(sj_train_preds, sj_test_preds))

# %%
fig, ax = plt.subplots(figsize = (15,10))
output_sj[0].plot(ax = ax)
ax.axvline(len(sj_train_preds), linestyle = 'dashed', color = 'black')
ax.set_ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
iq_feature_train_log_cases = iq_feature_train.copy()
iq_feature_train_log_cases['total_cases'] = np.log(1 + iq_feature_train_log_cases['total_cases'])

# %%
iq_model, iq_train_preds, iq_test_preds = fit_and_predict_LSTM(iq_feature_train.iloc[70:,:], iq_feature_test, epochs = 50, n_hidden = 40, verbose = 2)
# Out:
# Train on 230 samples, validate on 200 samples
# Epoch 1/50
#  - 1s - loss: 8.6189 - val_loss: 8.8789
# Epoch 2/50
#  - 0s - loss: 8.4563 - val_loss: 8.7759
# Epoch 3/50
#  - 0s - loss: 8.3501 - val_loss: 8.6667
# Epoch 4/50
#  - 0s - loss: 8.1659 - val_loss: 8.5481
# Epoch 5/50
#  - 0s - loss: 8.0295 - val_loss: 8.4107
# Epoch 6/50
#  - 0s - loss: 7.9047 - val_loss: 8.2571
# Epoch 7/50
#  - 0s - loss: 7.6329 - val_loss: 8.0846
# Epoch 8/50
#  - 0s - loss: 7.5277 - val_loss: 7.9025
# Epoch 9/50
#  - 0s - loss: 7.3220 - val_loss: 7.7088
# Epoch 10/50
#  - 0s - loss: 7.0675 - val_loss: 7.5054
# Epoch 11/50
#  - 0s - loss: 6.9060 - val_loss: 7.3079
# Epoch 12/50
#  - 0s - loss: 6.7675 - val_loss: 7.1190
# Epoch 13/50
#  - 0s - loss: 6.5305 - val_loss: 6.9446
# Epoch 14/50
#  - 0s - loss: 6.4949 - val_loss: 6.8023
# Epoch 15/50
#  - 0s - loss: 6.3713 - val_loss: 6.6805
# Epoch 16/50
#  - 0s - loss: 6.2671 - val_loss: 6.5677
# Epoch 17/50
#  - 0s - loss: 6.2301 - val_loss: 6.4784
# Epoch 18/50
#  - 0s - loss: 6.2304 - val_loss: 6.4142
# Epoch 19/50
#  - 0s - loss: 6.3433 - val_loss: 6.3764
# Epoch 20/50
#  - 0s - loss: 6.0728 - val_loss: 6.3558
# Epoch 21/50
#  - 0s - loss: 5.9296 - val_loss: 6.3428
# Epoch 22/50
#  - 0s - loss: 6.0727 - val_loss: 6.3272
# Epoch 23/50
#  - 0s - loss: 5.9868 - val_loss: 6.3043
# Epoch 24/50
#  - 0s - loss: 6.1176 - val_loss: 6.2734
# Epoch 25/50
#  - 0s - loss: 5.9436 - val_loss: 6.2486
# Epoch 26/50
#  - 0s - loss: 6.0330 - val_loss: 6.2389
# Epoch 27/50
#  - 0s - loss: 5.7720 - val_loss: 6.2359
# Epoch 28/50
#  - 0s - loss: 5.9260 - val_loss: 6.2331
# Epoch 29/50
#  - 0s - loss: 5.7187 - val_loss: 6.2308
# Epoch 30/50
#  - 0s - loss: 5.8654 - val_loss: 6.2269
# Epoch 31/50
#  - 0s - loss: 5.7695 - val_loss: 6.2219
# Epoch 32/50
#  - 0s - loss: 5.8851 - val_loss: 6.2215
# Epoch 33/50
#  - 0s - loss: 5.7399 - val_loss: 6.2254
# Epoch 34/50
#  - 0s - loss: 5.7434 - val_loss: 6.2307
# Epoch 35/50
#  - 0s - loss: 5.6574 - val_loss: 6.2374
# Epoch 36/50
#  - 0s - loss: 5.4470 - val_loss: 6.2420
# Epoch 37/50
#  - 0s - loss: 5.6992 - val_loss: 6.2521
# Epoch 38/50
#  - 0s - loss: 5.5565 - val_loss: 6.2662
# Epoch 39/50
#  - 0s - loss: 5.4956 - val_loss: 6.2793
# Epoch 40/50
#  - 0s - loss: 5.3928 - val_loss: 6.2863
# Epoch 41/50
#  - 0s - loss: 5.4048 - val_loss: 6.2924
# Epoch 42/50
#  - 0s - loss: 5.5632 - val_loss: 6.3038
# Epoch 43/50
#  - 0s - loss: 5.5042 - val_loss: 6.3199
# Epoch 44/50
#  - 0s - loss: 5.4412 - val_loss: 6.3335
# Epoch 45/50
#  - 0s - loss: 5.3785 - val_loss: 6.3438
# Epoch 46/50
#  - 0s - loss: 5.5483 - val_loss: 6.3550
# Epoch 47/50
#  - 0s - loss: 5.1690 - val_loss: 6.3614
# Epoch 48/50
#  - 0s - loss: 5.1798 - val_loss: 6.3697
# Epoch 49/50
#  - 0s - loss: 5.1361 - val_loss: 6.3753
# Epoch 50/50
#  - 0s - loss: 5.1928 - val_loss: 6.3790

# %%
output_iq = pd.DataFrame(np.append(iq_train_preds, iq_test_preds))
output_iq['total_cases'] = np.expm1(output_iq[0]).astype(int)

# %%
fig, ax = plt.subplots(figsize = (15,10))
output_iq['total_cases'].plot(ax = ax)
ax.axvline(len(iq_train_preds), linestyle = 'dashed', color = 'black')
ax.set_ylabel('total_cases')
# Out:
# Text(0, 0.5, 'total_cases')

# %%
# Finalize model
sj_model = pd.DataFrame(sj_test_preds.astype(int), columns = ['total_cases'])
sj_model['year'] = sj_feature_test['year']
sj_model['weekofyear'] = sj_feature_test['weekofyear']
sj_model['city'] = 'sj'

# %%
iq_model = pd.DataFrame(iq_test_preds.astype(int), columns = ['total_cases'])
iq_model['year'] = iq_feature_test['year']
iq_model['weekofyear'] = iq_feature_test['weekofyear']
iq_model['city'] = 'iq'

# %%
model = sj_model.append(iq_model)[['city', 'year', 'weekofyear', 'total_cases']]
model.loc[model['total_cases'] < 0, 'total_cases'] = 0

# %%
model
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18            3
# 1     sj  2008          19            4
# 2     sj  2008          20            5
# 3     sj  2008          21            8
# 4     sj  2008          22           13
# ..   ...   ...         ...          ...
# 151   iq  2013          22            3
# 152   iq  2013          23            2
# 153   iq  2013          24            2
# 154   iq  2013          25            2
# 155   iq  2013          26            3
#
# [416 rows x 4 columns]

# %%
model[model['city'] == 'sj']['total_cases'].plot()

# %%
model[model['city'] == 'iq']['total_cases'].plot()

# %%
import time
today = time.strftime('%d-%m-%Y')
model.to_csv(model_path + '/Keras_LSTM_' + output_feature_fname + '_' + today + '.csv', index = False)
